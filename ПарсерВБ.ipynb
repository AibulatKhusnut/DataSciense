# %%
import requests

headers = {
    'Accept': '*/*',
    'Accept-Language': 'ru-RU,ru;q=0.9',
    'Connection': 'keep-alive',
    'Origin': 'https://www.wildberries.ru',
    'Referer': 'https://www.wildberries.ru/catalog/elektronika/tv-audio-foto-video-tehnika/televizory/televizory?sort=popular&page=1&fbrand=5772',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'cross-site',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36',
    'sec-ch-ua': '"Chromium";v="118", "Google Chrome";v="118", "Not=A?Brand";v="99"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
}

response = requests.get(
    'https://catalog.wb.ru/catalog/electronic13/catalog?TestGroup=mp_rec_srch_infra&TestID=333&appType=1&curr=rub&dest=-1257786&fbrand=5772&page=1&regions=80,83,38,4,64,33,68,70,30,40,86,75,69,1,66,110,22,48,31,71,112,114&sort=popular&spp=27&subject=2819',
    headers=headers,
)

# %%
print(response.status_code)
print(response.json())
# Out:
# 200
# ...

# %%
import requests
import re
import csv
url = "https://www.wildberries.ru/catalog/elektronika/tv-audio-foto-video-tehnika/televizory/televizory?sort=popular&page=1&fbrand=5772"
class ParseWB:
    def __unit__(self, url:str):
        self.drand_id = self.__get_brand_id(url)
        
    @staticmethod
    def __get_brand_id(url:str):
        regex = "(?<=brand=).+"
        brand_id = re.search(regex, url)[0]
        return brand_id
    
    def parse(self):
        i = 1
        while True:
            response = requests.get(
            f'https://catalog.wb.ru/catalog/electronic13/catalog?TestGroup=mp_rec_srch_infra&TestID=333&appType=1&curr=rub&dest=-1257786&fbrand={self.brand_id}&page={i}&regions=80,83,38,4,64,33,68,70,30,40,86,75,69,1,66,110,22,48,31,71,112,114&sort=popular&spp=27&subject=2819',
            )
            i+=1
            print(response.status_code)
            print(response.json)
            print(brand_id)
    def __create__csv(self):
        with open("wb_data.csv", mode="w", newline="") as file:
            writer  = csv.writer(file)
            writer.writerow(['id', 'название', 'цена', 'бренд', 'продаж', 'рейтинг',  'в наличии'])
            
    def save_csv(self):
        pass
    
    

    
    
    
#if __name__ == "__main__":
    #ParseWB('https://www.wildberries.ru/catalog/elektronika/tv-audio-foto-video-tehnika/televizory/televizory?sort=popular&page=1&fbrand=5772').parse()
